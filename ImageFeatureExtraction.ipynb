# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c8ec22b3e787> in <module>()
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# !pip install opencv-python
# Out:
# ...
# You are using pip version 9.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import cv2

# %%
imagePath="C:/Users/akskulka/Pictures/Saved Pictures/image.jfif"

# %%
image=cv2.imread(imagePath)

# %%
import matplotlib
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (183, 275, 3)

# %%
image
# Out:
# array([[[ 53, 144,  95],
#         [ 52, 144,  95],
#         [ 52, 144,  97],
#         ...,
#         [ 55, 114,  83],
#         [ 55, 112,  79],
#         [ 52, 109,  76]],
#
#        [[ 53, 144,  95],
#         [ 53, 144,  95],
#         [ 52, 144,  97],
#         ...,
#         [ 57, 117,  86],
#         [ 58, 115,  82],
#         [ 55, 112,  79]],
#
#        [[ 54, 143,  94],
#         [ 52, 143,  94],
#         [ 52, 142,  96],
#         ...,
#         [ 61, 121,  90],
#         [ 60, 119,  88],
#         [ 57, 116,  85]],
#
#        ...,
#
#        [[ 80, 120, 172],
#         [ 84, 127, 178],
#         [ 92, 137, 188],
#         ...,
#         [ 54,  91,  51],
#         [ 57,  94,  54],
#         [ 60,  97,  57]],
#
#        [[ 87, 133, 187],
#         [ 86, 133, 187],
#         [ 88, 135, 189],
#         ...,
#         [ 53,  92,  54],
#         [ 53,  95,  54],
#         [ 58,  98,  57]],
#
#        [[ 84, 135, 191],
#         [ 81, 135, 190],
#         [ 79, 133, 188],
# ...

# %%
size=(64,64)

# %%
resized=cv2.resize(image,size)

# %%
resized
# Out:
# array([[[ 52, 144,  96],
#         [ 46, 144,  98],
#         [ 50, 139,  96],
#         ...,
#         [153, 178, 170],
#         [ 93, 149, 126],
#         [ 57, 116,  84]],
#
#        [[ 55, 140,  93],
#         [ 52, 139,  95],
#         [ 58, 137,  96],
#         ...,
#         [153, 177, 169],
#         [100, 153, 130],
#         [ 64, 126,  95]],
#
#        [[ 59, 137,  91],
#         [ 62, 135,  93],
#         [ 67, 135,  96],
#         ...,
#         [154, 176, 169],
#         [108, 156, 134],
#         [ 63, 125,  96]],
#
#        ...,
#
#        [[120, 167, 200],
#         [ 93, 141, 182],
#         [ 93, 135, 175],
#         ...,
#         [151, 170, 156],
#         [ 89, 117,  84],
#         [ 73, 101,  61]],
#
#        [[101, 138, 183],
#         [ 99, 149, 195],
#         [100, 145, 185],
#         ...,
#         [136, 158, 146],
#         [ 76, 110,  80],
#         [ 62,  96,  56]],
#
#        [[ 87, 134, 188],
#         [110, 158, 207],
#         [128, 165, 198],
# ...

# %%
plt.imshow(resized)

# %%
resized_flattened=resized.flatten()

# %%
plt.imshow(resized_flattened)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-99844b1265ce> in <module>()
# ----> 1 plt.imshow(resized_flattened)
#
# C:\Users\Public\Miniconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3099                         filternorm=filternorm, filterrad=filterrad,
#    3100                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3101                         **kwargs)
#    3102     finally:
#    3103         ax._hold = washold
#
# C:\Users\Public\Miniconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# ...
