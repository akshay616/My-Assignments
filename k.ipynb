# %%
url="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# %%
import csv
with open("C:/Users/akskulka/Documents/Machine Learning/headBrain.csv") as csv_file:
    lines=csv.reader(csv_file)
    for row in lines:
        print(row)
# Out:
# ['Gender', 'Age Range', 'Head Size(cm^3)', 'Brain Weight(grams)', '']
# ['1', '1', '4512', '1530', '']
# ['1', '1', '3738', '1297', '']
# ['1', '1', '4261', '1335', '']
# ['1', '1', '3777', '1282', '']
# ['1', '1', '4177', '1590', '']
# ['1', '1', '3585', '1300', '']
# ['1', '1', '3785', '1400', '']
# ['1', '1', '3559', '1255', '']
# ['1', '1', '3613', '1355', '']
# ['1', '1', '3982', '1375', '']
# ['1', '1', '3443', '1340', '']
# ['1', '1', '3993', '1380', '']
# ['1', '1', '3640', '1355', '']
# ['1', '1', '4208', '1522', '']
# ['1', '1', '3832', '1208', '']
# ['1', '1', '3876', '1405', '']
# ['1', '1', '3497', '1358', '']
# ['1', '1', '3466', '1292', '']
# ['1', '1', '3095', '1340', '']
# ['1', '1', '4424', '1400', '']
# ['1', '1', '3878', '1357', '']
# ['1', '1', '4046', '1287', '']
# ['1', '1', '3804', '1275', '']
# ['1', '1', '3710', '1270', '']
# ['1', '1', '4747', '1635', '']
# ['1', '1', '4423', '1505', '']
# ['1', '1', '4036', '1490', '']
# ['1', '1', '4022', '1485', '']
# ...
